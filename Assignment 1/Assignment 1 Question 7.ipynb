# %% [markdown]
# # Questions:
# - Calculate the probability of a name being of a male or female base on the last character(s) of name

# %%
import nltk

m_names = nltk.corpus.names.words('male.txt')
f_names= nltk.corpus.names.words('female.txt')
for word in m_names:
    all_names.append(m_names)
for word in f_names:
    all_names.append(f_names)

# %%
import string
import nltk


def display(inp):
    probm = ((len(male_names_a))/(len(all_names_a)))*100
    probf = ((len(female_names_a))/(len(all_names_a)))*100
    print("Probability of names end with",inp)
    print("M:" + str(round(probm)) + "%")
    print("F:" + str(round(probf)) + "%")
    del all_names_a[0:]
    del male_names_a[0:]
    del female_names_a[0:]

all_names_a = []
male_names_a = []
female_names_a = []


  
all_names = []

m_names = nltk.corpus.names.words('male.txt')

f_names= nltk.corpus.names.words('female.txt')
for x in m_names:
      all_names.append(x)
for x in f_names:
    all_names.append(x)
    
print(len(male_names))
print(len(female_names))
print(len(all_names))

alpha = list(string.ascii_lowercase)
    

def callloop(inp_param):
    flag = 0
    for name in all_names:
        if len(name)!=0:
            if name.endswith(inp_param):
                flag = 1
                all_names_a.append(name)
          
    for name1 in m_names:
        if len(name1)!=0:
            if name1.endswith(inp_param):
                male_names_a.append(name1)
            
    for name2 in f_names:
        if len(name2)!=0:
            if name2.endswith(inp_param):
                female_names_a.append(name2)
           
    if flag == 1:
        display(inp_param)

for x in alpha:
    callloop(x)
# Out:
# 2943
# 5001
# 7944
# Probability of names end with a
# M:2%
# F:98%
# Probability of names end with b
# M:70%
# F:30%
# Probability of names end with c
# M:100%
# F:0%
# Probability of names end with d
# M:85%
# F:15%
# Probability of names end with e
# M:25%
# F:75%
# Probability of names end with f
# M:93%
# F:7%
# Probability of names end with g
# M:76%
# F:24%
# Probability of names end with h
# M:47%
# F:53%
# Probability of names end with i
# M:14%
# F:86%
# Probability of names end with j
# M:75%
# F:25%
# Probability of names end with k
# M:96%
# F:4%
# Probability of names end with l
# M:51%
# F:49%
# Probability of names end with m
# M:84%
# F:16%
# Probability of names end with n
# M:55%
# F:45%
# Probability of names end with o
# M:83%
# F:17%
# Probability of names end with p
# M:90%
# F:10%
# Probability of names end with r
# M:80%
# F:20%
# Probability of names end with s
# M:71%
# F:29%
# Probability of names end with t
# M:71%
# F:29%
# ...
